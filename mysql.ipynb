# %% [markdown]
# <a href="https://colab.research.google.com/github/payal1403/payal1403/blob/pythonfile/mysql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mysql-connector-python
# !apt-get -y install mysql-server
# !sudo service mysql start
# !sudo service status mysql
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# mysql-server is already the newest version (8.0.36-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
#  * Starting MySQL database server mysqld
#    ...done.
# status: unrecognized service

# %%
# !apt-get -y install mysql-server
# !sudo service mysql start

# !mysql -e "ALTER USER 'root'@'localhost' IDENTIFIED BY 'root';FLUSH PRIVILEGES;"
# !sudo mysql -u root -p
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# mysql-server is already the newest version (8.0.36-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
#  * Starting MySQL database server mysqld
#    ...done.
# Enter password:
# Welcome to the MySQL monitor.  Commands end with ; or \g.
# Your MySQL connection id is 30
# Server version: 8.0.36-0ubuntu0.22.04.1 (Ubuntu)
#
# Copyright (c) 2000, 2024, Oracle and/or its affiliates.
#
# Oracle is a registered trademark of Oracle Corporation and/or its
# affiliates. Other names may be trademarks of their respective
# owners.
#
# Type 'help;' or '\h' for help. Type '\c' to clear the current input statement.
#
# mysql> ^C
# mysql> ^C
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-4b850e4b610a> in <cell line: 5>()
#       3
# ...

# %%
# !apt-get -y install mysql-server
# !sudo service mysql start

# !mysql -e "ALTER USER 'root'@'localhost' IDENTIFIED BY 'root';FLUSH PRIVILEGES;"
# !mysql select * from user
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# mysql-server is already the newest version (8.0.36-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 32 not upgraded.
#  * Starting MySQL database server mysqld
#    ...done.
# mysql  Ver 8.0.36-0ubuntu0.22.04.1 for Linux on x86_64 ((Ubuntu))
# Copyright (c) 2000, 2024, Oracle and/or its affiliates.
#
# Oracle is a registered trademark of Oracle Corporation and/or its
# affiliates. Other names may be trademarks of their respective
# owners.
#
# Usage: mysql [OPTIONS] [database]
#   -?, --help          Display this help and exit.
#   -I, --help          Synonym for -?
#   --auto-rehash       Enable automatic rehashing. One doesn't need to use
#                       'rehash' to get table and field completion, but startup
#                       and reconnecting may take a longer time. Disable with
#                       --disable-auto-rehash.
# ...

# %%
# !mysql -e "create table mysql.end_users (Name char(20),City char(20) )"

# %%
# !mysql select * from end_users
# Out:
# mysql  Ver 8.0.36-0ubuntu0.22.04.1 for Linux on x86_64 ((Ubuntu))
# Copyright (c) 2000, 2024, Oracle and/or its affiliates.
#
# Oracle is a registered trademark of Oracle Corporation and/or its
# affiliates. Other names may be trademarks of their respective
# owners.
#
# Usage: mysql [OPTIONS] [database]
#   -?, --help          Display this help and exit.
#   -I, --help          Synonym for -?
#   --auto-rehash       Enable automatic rehashing. One doesn't need to use
#                       'rehash' to get table and field completion, but startup
#                       and reconnecting may take a longer time. Disable with
#                       --disable-auto-rehash.
#                       (Defaults to on; use --skip-auto-rehash to disable.)
#   -A, --no-auto-rehash
#                       No automatic rehashing. One has to use 'rehash' to get
#                       table and field completion. This gives a quicker start of
# ...

# %%
# !mysql -e  "INSERT INTO mysql.end_users(Name,City)  VALUES ('mansha','Jaipur'),('zoo','Ajmer');"
! mysql -e "select * from mysql.end_users"
# Out:
# +--------+--------+
# | Name   | City   |
# +--------+--------+
# | Payal  | Jaipur |
# | Payal  | Jaipur |
# | Payal  | Jaipur |
# | Neha   | Ajmer  |
# | Payal  | Jaipur |
# | Neha   | Ajmer  |
# | Payal  | Jaipur |
# | Neha   | Ajmer  |
# | Payal  | Jaipur |
# | Neha   | Ajmer  |
# | mansha | Jaipur |
# | zoo    | Ajmer  |
# +--------+--------+

# %%
# !mysql -e  "INSERT INTO mysql.end_users(Name,City)  VALUES ('Mansha','Jaipur'),('Zoo','Ajmer'),('Payal','Udaipur'),('Neha','Amer');"
! mysql -e "select * from mysql.end_users"
# Out:
# +--------+---------+
# | Name   | City    |
# +--------+---------+
# | mansha | Jaipur  |
# | zoo    | Ajmer   |
# | Mansha | Jaipur  |
# | Zoo    | Ajmer   |
# | Payal  | Udaipur |
# | Neha   | Amer    |
# +--------+---------+
